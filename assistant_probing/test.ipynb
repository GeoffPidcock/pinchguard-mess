# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from assistant_probing.axis_download import download_axis, load_axis

# --- configure paths here ---
AXIS_DIR = Path.cwd() / "data" / "axis"
# ----------------------------

axis_path = download_axis("Qwen/Qwen3-32B", AXIS_DIR)
axis = load_axis(axis_path)
print(f"axis loaded, shape: {axis.shape}")
# Out:
# axis loaded, shape: torch.Size([64, 5120])

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from assistant_probing.projection import run_probe, save_csv

# --- configure paths here ---
AXIS_DIR = Path.cwd() / "data" / "axis"
ACTIVATIONS_DIR = Path.cwd().parent / "data" / "runs" / "scenario_02_baseline" / "activations"
PROJECTION_DIR = Path.cwd() / "data" / "projections" / "scenario_02_baseline"
RUN_NAME = "scenario_02_baseline"
# ----------------------------

scores = run_probe(ACTIVATIONS_DIR, axis_dir=AXIS_DIR)
for turn, (name, score) in enumerate(scores):
    print(f"turn {turn:>2}  label_probe = {score: 9.4f}   {name}")

out_path = save_csv(scores, RUN_NAME, output_dir=PROJECTION_DIR)
print(f"saved to {out_path}")
# Out:
# turn  0  label_probe =  -19.5419   02c43520-f529-4767-8239-d1c86ec2c566.npz
# turn  1  label_probe =  -20.3470   09d8f389-2914-4216-b734-05428f0c8192.npz
# turn  2  label_probe =  -19.3902   09e5d423-aba1-46c0-9a2c-e8593e44b27a.npz
# turn  3  label_probe =  -21.6565   0adde25e-a87c-493e-ab92-9b3724f4fdba.npz
# turn  4  label_probe =  -19.9636   5147fca9-f044-468c-a1f8-2bf01ed882c0.npz
# turn  5  label_probe =  -19.7668   54c01539-fd81-41a5-bd73-629d4d2d1208.npz
# turn  6  label_probe =  -21.0865   56cb8214-dd48-4f77-8c7e-1e3c9c97fbd1.npz
# turn  7  label_probe =  -21.4124   77fc26d6-5dc3-49dc-9f07-4348c434b550.npz
# turn  8  label_probe =  -19.7514   81c266cb-717b-4761-8c59-777b8a4991ed.npz
# turn  9  label_probe =  -20.3530   90969e73-5377-436c-ab95-7e59eeb3256d.npz
# turn 10  label_probe =  -19.3878   bb852a6f-38a0-434b-8081-2ee9b8fde2c3.npz
# turn 11  label_probe =  -19.4047   c014f119-c414-4f83-a9f3-3123f8374bc2.npz
# turn 12  label_probe =  -20.1516   cd16981e-37e6-4fa3-8563-aa4be51656ae.npz
# turn 13  label_probe =  -19.3588   e7da96f2-aa27-487b-882c-670c39047b34.npz
# turn 14  label_probe =  -23.0377   ea64dc05-5028-40ba-9301-b703dd2942a6.npz
# saved to c:\Users\THINKPAD T14\OneDrive\Documents\000 THINKPAD\Projects\Collab\Local Pinchguard\home\lion\pinchguard\assistant_probing\data\projections\scenario_02_baseline\scenario_02_baseline.csv

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from assistant_probing.projection import run_probe, save_csv

# --- configure paths here ---
AXIS_DIR = Path.cwd() / "data" / "axis"
ACTIVATIONS_DIR = Path.cwd().parent / "data" / "runs" / "scenario_04_contaminated" / "activations"
PROJECTION_DIR = Path.cwd() / "data" / "projections" / "scenario_04_contaminated"
RUN_NAME = "scenario_04_contaminated"
# ----------------------------

scores = run_probe(ACTIVATIONS_DIR, axis_dir=AXIS_DIR)
for turn, (name, score) in enumerate(scores):
    print(f"turn {turn:>2}  label_probe = {score: 9.4f}   {name}")

out_path = save_csv(scores, RUN_NAME, output_dir=PROJECTION_DIR)
print(f"saved to {out_path}")
# Out:
# saved to c:\Users\THINKPAD T14\OneDrive\Documents\000 THINKPAD\Projects\Collab\Local Pinchguard\home\lion\pinchguard\assistant_probing\data\projections\scenario_04_contaminated_20260608T080306Z\scenario_04_contaminated_20260608T080306Z.csv

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from assistant_probing.projection import run_probe, save_csv

# --- configure paths here ---
AXIS_DIR = Path.cwd() / "data" / "axis"
ACTIVATIONS_DIR = Path.cwd().parent / "data" / "runs" / "scenario_04_contaminated_20260608T085238Z" / "activations"
PROJECTION_DIR = Path.cwd() / "data" / "projections" / "scenario_04_contaminated_20260608T085238Z"
RUN_NAME = "scenario_04_contaminated_20260608T085238Z"
# ----------------------------

scores = run_probe(ACTIVATIONS_DIR, axis_dir=AXIS_DIR)
for turn, (name, score) in enumerate(scores):
    print(f"turn {turn:>2}  label_probe = {score: 9.4f}   {name}")

out_path = save_csv(scores, RUN_NAME, output_dir=PROJECTION_DIR)
print(f"saved to {out_path}")

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from assistant_probing.projection import run_probe, save_csv

# --- configure paths here ---
AXIS_DIR = Path.cwd() / "data" / "axis"
ACTIVATIONS_DIR = Path.cwd().parent / "data" / "runs" / "scenario_05_malicious" / "activations"
PROJECTION_DIR = Path.cwd() / "data" / "projections" / "scenario_05_malicious"
RUN_NAME = "scenario_05_malicious"
# ----------------------------

scores = run_probe(ACTIVATIONS_DIR, axis_dir=AXIS_DIR)
for turn, (name, score) in enumerate(scores):
    print(f"turn {turn:>2}  label_probe = {score: 9.4f}   {name}")

out_path = save_csv(scores, RUN_NAME, output_dir=PROJECTION_DIR)
print(f"saved to {out_path}")
